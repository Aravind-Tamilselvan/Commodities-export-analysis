# %% [markdown]
# Commodities exported from APRIL 2024- APRIL 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('../excel/commodities 2024-2025.xlsx')
df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0     1.0     1.0                                      LIVE ANIMALS.
# 1     2.0     2.0                        MEAT AND EDIBLE MEAT OFFAL.
# 2     3.0     3.0  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3     4.0     4.0  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4     5.0     5.0  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94   95.0    96.0               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95   96.0    97.0      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96   97.0    98.0                  PROJECT GOODS; SOME SPECIAL USES.
# 97   98.0    99.0                               MISCELLANEOUS GOODS.
# 98    NaN     NaN                               India's Total Export
#
#     Apr-2024\n(F)  Apr - 2025\n(F)  % Growth  Apr - Apr 2024\n(F)  \
# 0            1.97             1.54    -21.49                 1.97
# 1          261.95           287.27      9.67               261.95
# 2          424.74           487.90     14.87               424.74
# 3           54.42            77.22     41.88                54.42
# 4           10.99            20.76     88.83                10.99
# ..            ...              ...       ...                  ...
# 94          59.85            62.28      4.06                59.85
# 95           6.90            14.98    117.08                 6.90
# 96           1.75             0.65    -62.77                 1.75
# 97           0.03             0.02    -34.98                 0.03
# 98       35303.60         38461.88      8.95             35303.60
#
#     Apr - Apr 2025\n(F)  % Growth_1
# 0                  1.54      -21.49
# 1                287.27        9.67
# 2                487.90       14.87
# 3                 77.22       41.88
# 4                 20.76       88.83
# ..                  ...         ...
# 94                62.28        4.06
# 95                14.98      117.08
# 96                 0.65      -62.77
# 97                 0.02      -34.98
# 98             38461.88        8.95
#
# [99 rows x 9 columns]

# %%
# Change datatype of S.NO and HSCode
df = df.astype({'S.No.':'Int64','HSCode':'Int64'})
df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2024\n(F)  Apr - 2025\n(F)  % Growth  Apr - Apr 2024\n(F)  \
# 0            1.97             1.54    -21.49                 1.97
# 1          261.95           287.27      9.67               261.95
# 2          424.74           487.90     14.87               424.74
# 3           54.42            77.22     41.88                54.42
# 4           10.99            20.76     88.83                10.99
# ..            ...              ...       ...                  ...
# 94          59.85            62.28      4.06                59.85
# 95           6.90            14.98    117.08                 6.90
# 96           1.75             0.65    -62.77                 1.75
# 97           0.03             0.02    -34.98                 0.03
# 98       35303.60         38461.88      8.95             35303.60
#
#     Apr - Apr 2025\n(F)  % Growth_1
# 0                  1.54      -21.49
# 1                287.27        9.67
# 2                487.90       14.87
# 3                 77.22       41.88
# 4                 20.76       88.83
# ..                  ...         ...
# 94                62.28        4.06
# 95                14.98      117.08
# 96                 0.65      -62.77
# 97                 0.02      -34.98
# 98             38461.88        8.95
#
# [99 rows x 9 columns]

# %%
new_df = df.loc[:,~df.T.duplicated()]
new_df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2024\n(F)  Apr - 2025\n(F)  % Growth
# 0            1.97             1.54    -21.49
# 1          261.95           287.27      9.67
# 2          424.74           487.90     14.87
# 3           54.42            77.22     41.88
# 4           10.99            20.76     88.83
# ..            ...              ...       ...
# 94          59.85            62.28      4.06
# 95           6.90            14.98    117.08
# 96           1.75             0.65    -62.77
# 97           0.03             0.02    -34.98
# 98       35303.60         38461.88      8.95
#
# [99 rows x 6 columns]

# %%
new_df.loc[:, 'Commodity'] = new_df['Commodity'].str.replace('\n',' ',regex=False)
new_df.columns = new_df.columns.str.replace('\n',' ',regex=False)
new_df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2024 (F)  Apr - 2025 (F)  % Growth
# 0           1.97            1.54    -21.49
# 1         261.95          287.27      9.67
# 2         424.74          487.90     14.87
# 3          54.42           77.22     41.88
# 4          10.99           20.76     88.83
# ..           ...             ...       ...
# 94         59.85           62.28      4.06
# 95          6.90           14.98    117.08
# 96          1.75            0.65    -62.77
# 97          0.03            0.02    -34.98
# 98      35303.60        38461.88      8.95
#
# [99 rows x 6 columns]

# %%
new_df.to_excel('commodities 2024-25.xlsx',index=False)
