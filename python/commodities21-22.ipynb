# %% [markdown]
# Commodities exported from APRIL 2021- APRIL 2022

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('../excel/commodities 2021-2022.xlsx')
df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0     1.0     1.0                                      LIVE ANIMALS.
# 1     2.0     2.0                        MEAT AND EDIBLE MEAT OFFAL.
# 2     3.0     3.0  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3     4.0     4.0  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4     5.0     5.0  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94   95.0    96.0               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95   96.0    97.0      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96   97.0    98.0                  PROJECT GOODS; SOME SPECIAL USES.
# 97   98.0    99.0                               MISCELLANEOUS GOODS.
# 98    NaN     NaN                               India's Total Export
#
#     Apr-2021\n(R)  Apr - 2022\n(R)  % Growth  Apr - Apr 2021\n(R)  \
# 0            0.53             0.77     44.70                 0.53
# 1          303.86           307.46      1.19               303.86
# 2          491.53           546.10     11.10               491.53
# 3           30.53            64.10    109.99                30.53
# 4           10.89            17.73     62.87                10.89
# ..            ...              ...       ...                  ...
# 94          50.06            71.04     41.92                50.06
# 95           2.70             3.55     31.43                 2.70
# 96           0.84             1.19     42.42                 0.84
# 97           3.49             3.55      1.67                 3.49
# 98       30750.58         39698.17     29.10             30750.58
#
#     Apr - Apr 2022\n(R)  % Growth_1
# 0                  0.77       44.70
# 1                307.46        1.19
# 2                546.10       11.10
# 3                 64.10      109.99
# 4                 17.73       62.87
# ..                  ...         ...
# 94                71.04       41.92
# 95                 3.55       31.43
# 96                 1.19       42.42
# 97                 3.55        1.67
# 98             39698.17       29.10
#
# [99 rows x 9 columns]

# %%
# Change datatype of S.NO and HSCode
df = df.astype({'S.No.':'Int64','HSCode':'Int64'})
df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2021\n(R)  Apr - 2022\n(R)  % Growth  Apr - Apr 2021\n(R)  \
# 0            0.53             0.77     44.70                 0.53
# 1          303.86           307.46      1.19               303.86
# 2          491.53           546.10     11.10               491.53
# 3           30.53            64.10    109.99                30.53
# 4           10.89            17.73     62.87                10.89
# ..            ...              ...       ...                  ...
# 94          50.06            71.04     41.92                50.06
# 95           2.70             3.55     31.43                 2.70
# 96           0.84             1.19     42.42                 0.84
# 97           3.49             3.55      1.67                 3.49
# 98       30750.58         39698.17     29.10             30750.58
#
#     Apr - Apr 2022\n(R)  % Growth_1
# 0                  0.77       44.70
# 1                307.46        1.19
# 2                546.10       11.10
# 3                 64.10      109.99
# 4                 17.73       62.87
# ..                  ...         ...
# 94                71.04       41.92
# 95                 3.55       31.43
# 96                 1.19       42.42
# 97                 3.55        1.67
# 98             39698.17       29.10
#
# [99 rows x 9 columns]

# %%
new_df = df.loc[:,~df.T.duplicated()]
new_df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER\nAQUA...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY;\nED...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE\nSPEC...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2021\n(R)  Apr - 2022\n(R)  % Growth
# 0            0.53             0.77     44.70
# 1          303.86           307.46      1.19
# 2          491.53           546.10     11.10
# 3           30.53            64.10    109.99
# 4           10.89            17.73     62.87
# ..            ...              ...       ...
# 94          50.06            71.04     41.92
# 95           2.70             3.55     31.43
# 96           0.84             1.19     42.42
# 97           3.49             3.55      1.67
# 98       30750.58         39698.17     29.10
#
# [99 rows x 6 columns]

# %%
new_df.loc[:, 'Commodity'] = new_df['Commodity'].str.replace('\n',' ',regex=False)
new_df.columns = new_df.columns.str.replace('\n',' ',regex=False)
new_df
# Out:
#     S.No.  HSCode                                          Commodity  \
# 0       1       1                                      LIVE ANIMALS.
# 1       2       2                        MEAT AND EDIBLE MEAT OFFAL.
# 2       3       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 3       4       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 4       5       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...
# ..    ...     ...                                                ...
# 94     95      96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 95     96      97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 96     97      98                  PROJECT GOODS; SOME SPECIAL USES.
# 97     98      99                               MISCELLANEOUS GOODS.
# 98   <NA>    <NA>                               India's Total Export
#
#     Apr-2021 (R)  Apr - 2022 (R)  % Growth
# 0           0.53            0.77     44.70
# 1         303.86          307.46      1.19
# 2         491.53          546.10     11.10
# 3          30.53           64.10    109.99
# 4          10.89           17.73     62.87
# ..           ...             ...       ...
# 94         50.06           71.04     41.92
# 95          2.70            3.55     31.43
# 96          0.84            1.19     42.42
# 97          3.49            3.55      1.67
# 98      30750.58        39698.17     29.10
#
# [99 rows x 6 columns]

# %%
new_df.to_excel('commodities 2021-22.xlsx',index=False)
